# %% [markdown]
# # TMDWF x-fit Normalize Template
#
# Normalize q0(x) samples from the x-space N-state fit using old bare matrix-element m0(bz) outputs.

# %%
from pathlib import Path
import sys

REPO_ROOT = Path.cwd()
SRC_DIR = REPO_ROOT / "src"
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

from lqcd_analysis.notebook_workflows import (
    pretty_print_config,
    render_tmdwf_xfit_normalize_input_text,
    run_tmdwf_xfit_normalize_from_notebook,
    validate_tmdwf_xfit_normalize_notebook_config,
)

# %%
workflow_config = {
    "title_pattern": "l64c64a076_m140_tmdwf_pz*",
    "input_root": str(REPO_ROOT / "results_tmdwf_x_nstate_fit"),
    "bare_matrix_root": str(REPO_ROOT / "results_tmdwf_fit"),
    "ns": 64,
    "lattice_spacing_fm": 0.076,
    "pzlist": [0],
    "gmlist": ["T5"],
    "etalist": ["eta0"],
    "bTlist": [0],
    "bzlist": [0, 2, 4, 6, 8, 10, 12],
    "component": "real",
    "nstates": 1,
    "normalization_mode": "mode1",
    "zstep_fm": 0.01,
    "interpolation_kind": "cubic",
    "results_dir": str(REPO_ROOT / "results_tmdwf_xfit_normalized"),
}

# %%
print(render_tmdwf_xfit_normalize_input_text(workflow_config))

# %%
validated = validate_tmdwf_xfit_normalize_notebook_config(workflow_config)
print(pretty_print_config(validated))

# %%
outputs = run_tmdwf_xfit_normalize_from_notebook(workflow_config)
outputs
