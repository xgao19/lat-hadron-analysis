# %% [markdown]
# # TMDWF Ratio Fourier-per-t Template
#
# Build bootstrap samples of q(x,t) directly from the TMDWF/C2pt ratio by Fourier transforming the bz dependence at each source-sink time.

# %%
from pathlib import Path
import sys

REPO_ROOT = Path.cwd()
SRC_DIR = REPO_ROOT / "src"
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

from lqcd_analysis.notebook_workflows import (
    pretty_print_config,
    render_tmdwf_ratio_fourier_t_input_text,
    run_tmdwf_ratio_fourier_t_from_notebook,
    validate_tmdwf_ratio_fourier_t_notebook_config,
)

# %%
workflow_config = {
    "title_pattern": "l64c64a076_m140_tmdwf_pz*",
    "ns": 64,
    "nt": 64,
    "lattice_spacing_fm": 0.076,
    "pzlist": [0],
    "gmlist": ["T5"],
    "etalist": ["eta0"],
    "Tdirlist": ["plus", "minus"],
    "bTlist": [0],
    "bzlist": [0, 2, 4, 6, 8, 10, 12],
    "component": "real",
    "qtmdwf_h5": "/path/to/qtmdwf_pz*.h5",
    "dataset_path_template": "{gm}/{eta}/pz{pz}/{Tdir}/bT{bT}/bz{bz}",
    "c2pt": "/path/to/c2pt_pz*_real.csv",
    "fold_t": "none",
    "tsrange": [0, 20],
    "x_range": [-0.5, 1.5],
    "x_count": 201,
    "zstep_fm": 0.01,
    "interpolation_kind": "cubic",
    "binsize": 1,
    "bootstrap_samples": "auto",
    "bootstrap_size": "auto",
    "seed": 2026,
    "results_dir": str(REPO_ROOT / "results_tmdwf_ratio_fourier_t"),
}

# %%
print(render_tmdwf_ratio_fourier_t_input_text(workflow_config))

# %%
validated = validate_tmdwf_ratio_fourier_t_notebook_config(workflow_config)
print(pretty_print_config(validated))

# %%
outputs = run_tmdwf_ratio_fourier_t_from_notebook(workflow_config)
outputs
