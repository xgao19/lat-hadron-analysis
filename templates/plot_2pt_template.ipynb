# %% [markdown]
# # 2pt Plot Template
#
# This notebook wraps the reusable 2pt plotting backend.
# It is intended for plotting existing fit outputs more transparently than a CLI-only workflow.

# %% [markdown]
# ## Imports / Setup

# %%
from pathlib import Path
import sys

REPO_ROOT = Path.cwd()
SRC_DIR = REPO_ROOT / "src"
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

from lqcd_analysis.notebook_workflows import pretty_print_config, run_plot_2pt_from_notebook

# %% [markdown]
# ## User Inputs
#
# Set these paths to files already produced by the 2pt N-state workflow.

# %%
plot_config = {
    "output_dir": "./plot_outputs",
    "correlator_table": "/path/to/results_nstate_fit/demo_pz0/tables/demo_pz0_normal_correlator_mean.txt",
    "meff_table": "/path/to/results_nstate_fit/demo_pz0/tables/demo_pz0_normal_effective_mass_tmax8.txt",
    "fit_table": "/path/to/results_nstate_fit/demo_pz0/tables/demo_pz0_normal_2state_tmax8_fits.txt",
    "nstates": 2,
    "model": "normal",
    "title": "demo_pz0",
    "nt": 64,
}

# %% [markdown]
# ## Input Summary

# %%
print(pretty_print_config(plot_config))

# %% [markdown]
# ## Run Plotting
#
# This calls the same plotting function used by the standalone plotting script.

# %%
plot_outputs = run_plot_2pt_from_notebook(plot_config)
for path in plot_outputs:
    print(path)

# %% [markdown]
# ## Notes / Next Steps
#
# - Edit `plot_config` to switch datasets or states.
# - Re-run only the last cell when changing plotting paths.
# - For custom styling, import functions directly from `lqcd_analysis.plotting_2pt` and modify them interactively.
